# %%
# Procedure 1: Creating a Class and Object

# Example - Car class
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

    def display_info(self):
        return f"{self.year} {self.brand} {self.model}"

my_car = Car("Toyota", "Corolla", 2022)
print(my_car.display_info())

# Try It - Laptop class
class Laptop:
    def __init__(self, brand, processor, ram):
        self.brand = brand
        self.processor = processor
        self.ram = ram

    def get_specs(self):
        return f"Brand: {self.brand} | Processor: {self.processor} | RAM: {self.ram}GB"

my_laptop = Laptop("Lenovo", "Intel i5", 8)
print(my_laptop.get_specs())
# Out:
# 2022 Toyota Corolla
# Brand: Lenovo | Processor: Intel i5 | RAM: 8GB

# %%
# Procedure 2: Encapsulation

# Example - BankAccount
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        return f"New balance: ${self.__balance}"

    def get_balance(self):
        return f"Balance: ${self.__balance}"

account = BankAccount("Alice", 5000)
print(account.deposit(1500))
print(account.get_balance())

# Try It - StudentRecord
class StudentRecord:
    def __init__(self):
        self.__grades = []

    def add_grade(self, grade):
        self.__grades.append(grade)
        return f"Grade {grade} added successfully."

    def get_grades(self):
        return f"Grades: {self.__grades}"

student = StudentRecord()
print(student.add_grade(92))
print(student.add_grade(88))
print(student.add_grade(95))
print(student.get_grades())
# Out:
# New balance: $6500
# Balance: $6500
# Grade 92 added successfully.
# Grade 88 added successfully.
# Grade 95 added successfully.
# Grades: [92, 88, 95]

# %%
# Procedure 3: Inheritance

# Example - Person and Student
class Person:
    def __init__(self, name):
        self.name = name

    def introduce(self):
        return f"Hi, I'm {self.name}."

class Student(Person):
    def introduce(self):
        return f"Hi, I'm {self.name}, and I'm a student."

person = Person("Allen")
student = Student("Prince AC")
print(person.introduce())
print(student.introduce())

# Try It - Device and Smartphone
class Device:
    def __init__(self, device_name):
        self.device_name = device_name

    def power_on(self):
        return f"{self.device_name} is turning on."

class Smartphone(Device):
    def power_on(self):
        return f"{self.device_name} is booting up... Welcome!"

device = Device("Generic Device")
phone = Smartphone("Samsung Galaxy")
print(device.power_on())
print(phone.power_on())
# Out:
# Hi, I'm Allen.
# Hi, I'm Prince AC, and I'm a student.
# Generic Device is turning on.
# Samsung Galaxy is booting up... Welcome!

# %%
# Procedure 4: Polymorphism

# Example - Shape, Circle, Rectangle
class Shape:
    def area(self):
        return "Calculating area..."

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)
print(f"Circle area: {circle.area()}")
print(f"Rectangle area: {rectangle.area()}")

# Try It - Device, Smartphone, Laptop
class Device:
    def power_on(self):
        return "Device is turning on."

class Smartphone(Device):
    def power_on(self):
        return "Smartphone is booting up... Loading apps!"

class Laptop(Device):
    def power_on(self):
        return "Laptop is starting up... Please wait."

def start_device(device):
    print(device.power_on())

phone = Smartphone()
laptop = Laptop()
start_device(phone)
start_device(laptop)
# Out:
# Circle area: 78.5
# Rectangle area: 24
# Smartphone is booting up... Loading apps!
# Laptop is starting up... Please wait.

# %%
# Procedure 5: Using Object-Oriented Libraries

# Example - datetime
import datetime
current_time = datetime.datetime.now()
print("Current Date and Time:", current_time.strftime("%Y-%m-%d %H:%M:%S"))

# Try It - random, os, platform
import random
import os
import platform

random_number = random.random()
print(f"Random number: {random_number}")
print(f"Operating System: {platform.system()}")
# Out:
# Current Date and Time: 2026-04-26 21:51:38
# Random number: 0.2064107783296587
# Operating System: Windows

# %%
# Procedure 6: Static Methods

# Example - MathOperations
class MathOperations:
    @staticmethod
    def square(num):
        return num * num

user_input = int(input("Enter a number to square: "))
result = MathOperations.square(user_input)
print("Square of", user_input, ":", result)

# Try It - TemperatureConverter
class TemperatureConverter:
    @staticmethod
    def celsius_to_fahrenheit(celsius):
        return (celsius * 9/5) + 32

celsius_input = float(input("Enter temperature in Celsius: "))
fahrenheit = TemperatureConverter.celsius_to_fahrenheit(celsius_input)
print(f"{celsius_input}°C is equal to {fahrenheit}°F")
# Out:
# Square of 4 : 16
# 754.0°C is equal to 1389.2°F

# %%
# Procedure 7: Operator Overloading

# Example - BankAccount
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def __add__(self, other):
        return BankAccount(self.balance + other.balance)

account1 = BankAccount(5000)
account2 = BankAccount(3000)
total_balance = account1 + account2
print(f"Total Balance: P{total_balance.balance}")

# Try It - Vector
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Vector(self.x - other.x, self.y - other.y)

    def __str__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(3, 5)
v2 = Vector(1, 2)
print(f"V1: {v1}")
print(f"V2: {v2}")
print(f"V1 + V2 = {v1 + v2}")
print(f"V1 - V2 = {v1 - v2}")
# Out:
# Total Balance: P8000
# V1: Vector(3, 5)
# V2: Vector(1, 2)
# V1 + V2 = Vector(4, 7)
# V1 - V2 = Vector(2, 3)

# %%
# Procedure 8: Abstract Classes

from abc import ABC, abstractmethod

class Appliance(ABC):
    @abstractmethod
    def turn_on(self):
        pass

class WashingMachine(Appliance):
    def turn_on(self):
        return "Washing machine is now running."

class Refrigerator(Appliance):
    def turn_on(self):
        return "Refrigerator is now cooling."

wm = WashingMachine()
fridge = Refrigerator()
print(wm.turn_on())
print(fridge.turn_on())
# Out:
# Washing machine is now running.
# Refrigerator is now cooling.

# %%
# Procedure 9: Method Resolution Order (MRO)

# Example
class A:
    def show(self):
        return "Class A"

class B(A):
    def show(self):
        return "Class B"

class C(A):
    def show(self):
        return "Class C"

class D(B, C):
    pass

obj = D()
print(obj.show())
print(D.mro())

# Try It
class A:
    def show(self):
        return "I am Class A"

class B(A):
    def show(self):
        return "I am Class B"

class C(A):
    def show(self):
        return "I am Class C"

class D(B, C):
    def show(self):
        return "I am Class D"

obj = D()
print(obj.show())
print("\nMRO of class D:")
print(D.mro())
# Out:
# Class B
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]
# I am Class D
#
# MRO of class D:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]
